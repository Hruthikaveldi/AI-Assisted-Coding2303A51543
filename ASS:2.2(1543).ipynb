# %% [markdown]
# <a href="https://colab.research.google.com/github/Hruthikaveldi/AI-Assisted-Coding2303A51543/blob/main/ASS%3A2.2(1543).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Task 1: Cleaning Sensor Data**

# %% [markdown]
# Scenario:
#
# ❖ You are cleaning IoT sensor data where negative values are invalid.
#
# ❖ Task:
#
# Use Gemini in Colab to generate a function that filters out all negative
# numbers from a list.
#
# ❖ Expected Output:
#
# ➢ Before/after list
#
# ➢ Screenshot of Colab execution

# %%
def get_negative_numbers(data_list):
    """Extracts all negative numbers from a given list."""
    return [num for num in data_list if num < 0]

# Get user input for sensor data
user_input = input("Enter a comma-separated list of numbers (e.g., 10, -5, 20, 0, -15): ")

# Convert the input string to a list of numbers
try:
    sensor_data_original = [int(x.strip()) for x in user_input.split(',')]
except ValueError:
    print("Invalid input. Please enter integer numbers separated by commas.")
    sensor_data_original = []

print(f"Original List: {sensor_data_original}")

# Apply the function to get negative numbers
negative_numbers_list = get_negative_numbers(sensor_data_original)

print(f"Extracted Negative Values: {negative_numbers_list}")
# Out:
# Enter a comma-separated list of numbers (e.g., 10, -5, 20, 0, -15): 10, -5, 20, 0, -15
# Original List: [10, -5, 20, 0, -15]
# Extracted Negative Values: [-5, -15]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Problem:** The goal was to filter IoT sensor data to remove invalid negative values and then, based on a follow-up request, specifically extract those negative values.
#
# **Solution:** A Python function `get_negative_numbers(data_list)` was generated. This function efficiently iterates through a list of numbers and returns a new list containing only the values that are less than zero. The code was made interactive, allowing the user to input a comma-separated list of numbers for analysis.
#
# **AI Observations:**
# *   **Functionality:** Gemini successfully generated a function that accurately identifies and extracts negative numbers.
# *   **Adaptability:** The AI was able to adapt the code based on user feedback, first including even number filtering (which was later removed) and then focusing solely on negative value extraction.
# *   **User Input Handling:** The AI also incorporated user input effectively, demonstrating how to parse a string of comma-separated numbers into a list of integers, including basic error handling for invalid input formats.
#
# **Output Example:**
# ```
# Original List: [10, -5, 20, 0, -1]
# Extracted Negative Values: [-5, -1]

# %% [markdown]
# # **Task 2: String Character Analysis**

# %% [markdown]
# ❖ Scenario:
#
# You are building a text-analysis feature.
#
# ❖ Task:
#
# Use Gemini to generate a Python function that counts vowels, consonants,
# and digits in a string.
#
# ❖ Expected Output:
#
# ➢ Working function
#
# ➢ Sample inputs and outputs

# %%
def analyze_string_characters(input_string):
    """Counts vowels, consonants, and digits in a given string."""
    vowels = "aeiouAEIOU"
    vowel_count = 0
    consonant_count = 0
    digit_count = 0

    for char in input_string:
        if char.isalpha():  # Check if the character is an alphabet
            if char in vowels:
                vowel_count += 1
            else:
                consonant_count += 1
        elif char.isdigit():  # Check if the character is a digit
            digit_count += 1

    return vowel_count, consonant_count, digit_count

# Get user input for string analysis
user_input_string = input("Enter a string for character analysis: ")

v, c, d = analyze_string_characters(user_input_string)

print(f"String: '{user_input_string}'")
print(f"  Vowels: {v}, Consonants: {c}, Digits: {d}")
# Out:
# Enter a string for character analysis: hello world 123
# String: 'hello world 123'
#   Vowels: 3, Consonants: 7, Digits: 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Problem:** The task was to create a text-analysis feature that counts the occurrences of vowels, consonants, and digits within a given string.
#
# **Solution:** A Python function `analyze_string_characters(input_string)` was generated. This function processes a string, categorizes each character as a vowel, consonant, or digit, and returns the respective counts. The implementation is case-insensitive for vowels and ignores any non-alphanumeric characters.
#
# **AI Observations:**
# *   **Comprehensive Logic:** Gemini provided a robust function that correctly handles character classification (vowels, consonants, digits) and deals with cases where characters are not alphabetic or numeric.
# *   **Clarity:** The function is well-structured and uses clear variable names (`vowels`, `vowel_count`, `consonant_count`, `digit_count`), making the logic easy to follow.
# *   **Efficiency:** The use of `char.isalpha()` and `char.isdigit()` is an efficient way to categorize characters.
# *   **User Input Integration:** Similar to Task 1, the AI successfully integrated user input to make the function interactive.
#
# **Output Example:**
# ```
# String: 'Veldi.Hruthika_1543'
#   Vowels: 5, Consonants: 8, Digits: 4
# ```

# %% [markdown]
# # **Task 3: Palindrome Check – Tool Comparison**

# %% [markdown]
# ❖ Scenario:
#
# You must decide which AI tool is clearer for string logic.
#
# ❖ Task:
#
# Generate a palindrome-checking function using Gemini and Copilot, then
# compare the results.
#
# ❖ Expected Output:
#
# ➢ Side-by-side code comparison
#
# ➢ Observations on clarity and structure

# %%
def is_palindrome_gemini(text):
    """
    Checks if a given string is a palindrome.
    Ignores non-alphanumeric characters and is case-insensitive.
    """
    # Clean the text: remove non-alphanumeric characters and convert to lowercase
    cleaned_text = ''.join(char.lower() for char in text if char.isalnum())

    # Check if the cleaned text is equal to its reverse
    return cleaned_text == cleaned_text[::-1]

# Sample inputs for Gemini's function
gemini_test_strings = [
    "madam",
    "A man, a plan, a canal: Panama",
    "hello",
    "Racecar",
    "12321",
    "Was it a car or a cat I saw?",
    "OpenAI"
]

print("--- Gemini's Palindrome Function Tests ---")
for s in gemini_test_strings:
    result = is_palindrome_gemini(s)
    print(f"'{s}': {result}")
print("\n")
# Out:
# --- Gemini's Palindrome Function Tests ---
# 'madam': True
# 'A man, a plan, a canal: Panama': True
# 'hello': False
# 'Racecar': True
# '12321': True
# 'Was it a car or a cat I saw?': True
# 'OpenAI': False

# %% [markdown]
# **Gemini's Palindrome Function with User Input**
#
# You can use the function generated by Gemini (`is_palindrome_gemini`) with your own input. Enter a string below to check if it's a palindrome.

# %%
# Get user input for palindrome check
user_input_palindrome = input("Enter a string to check if it's a palindrome: ")

# Call Gemini's function with user input
result_user_input = is_palindrome_gemini(user_input_palindrome)

print(f"'{user_input_palindrome}': {result_user_input}")
# Out:
# Enter a string to check if it's a palindrome: madam
# 'madam': True

# %% [markdown]
# **Copilot's Palindrome Function**

# %%
# Palindrome check with user input

def is_palindrome(text: str) -> bool:
    # Normalize: remove non-alphanumeric characters and lowercase
    cleaned = ''.join(ch.lower() for ch in text if ch.isalnum())
    return cleaned == cleaned[::-1]

# Take input from user
user_text = input("Enter a word or phrase: ")

# Check and display result
if is_palindrome(user_text):
    print("✅ It's a palindrome!")
else:
    print("❌ Not a palindrome.")
# Out:
# Enter a word or phrase: maame
# ❌ Not a palindrome.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Palindrome Check - Side-by-Side Code Comparison and Observations
#
# **Gemini's Palindrome Function (`is_palindrome_gemini`):**
# ```python
# def is_palindrome_gemini(text):
#     """
#     Checks if a given string is a palindrome.
#     Ignores non-alphanumeric characters and is case-insensitive.
#     """
#     # Clean the text: remove non-alphanumeric characters and convert to lowercase
#     cleaned_text = ''.join(char.lower() for char in text if char.isalnum())
#     # Check if the cleaned text is equal to its reverse
#     return cleaned_text == cleaned_text[::-1]
# ```
#
# **Copilot's Palindrome Function (`is_palindrome`):**
# ```python
# def is_palindrome(text: str) -> bool:
#     # Normalize: remove non-alphanumeric characters and lowercase
#     cleaned = ''.join(ch.lower() for ch in text if ch.isalnum())
#     return cleaned == cleaned[::-1]
# ```
#
# #### Observations on Clarity and Structure:
#
# *   **Core Logic - Identical & Highly Pythonic:**
#     *   **What we observed:** Both Gemini and Copilot use the *exact same* Python technique: `cleaned = ''.join(char.lower() for char in text if char.isalnum())` to prepare the string, and `return cleaned == cleaned[::-1]` to check for a palindrome. This pattern is standard and efficient in Python.
#     *   **Why it's clear:** This shows both AIs understand how to solve this specific problem in a very idiomatic and effective Python way. For a developer, this consistency is good because it aligns with common practices.
#
# *   **Function Definition & Type Hinting:**
#     *   **Copilot's Clarity Edge:** Copilot included `def is_palindrome(text: str) -> bool:`. The `text: str` tells you the function expects a string, and `-> bool` tells you it will return a boolean (True/False).
#     *   **Gemini's Approach:** Gemini's function was `def is_palindrome_gemini(text):` without these hints.
#     *   **Why it matters:** Type hints (Copilot's approach) are a modern Python feature that significantly improve code clarity and maintainability. They act like a contract for the function, making it easier for other developers (or even your future self) to understand how to use it correctly and for tools to catch potential errors before running the code.
#
# *   **Comments and Docstrings - Both Excellent, Slight Nuance:**
#     *   **What we observed:** Both provide helpful comments/docstrings explaining the cleaning step and the function's purpose.
#     *   **Gemini's Detail:** Gemini's docstring explicitly mentions "Checks if a given string is a palindrome. Ignores non-alphanumeric characters and is case-insensitive." This is a comprehensive explanation for a user.
#     *   **Copilot's Conciseness:** Copilot uses a more concise comment "# Normalize: remove non-alphanumeric characters and lowercase." which is still very clear.
#     *   **Why it matters:** Good documentation is crucial for clarity. Both perform well here, but Gemini's longer docstring is slightly more explicit about the function's behavior.
#
# *   **Modularity and User Interaction:**
#     *   **Copilot's Integration:** The Copilot code provided integrates the `input()` call and `print()` statements directly with the function definition, making it a ready-to-run script for interactive use.
#     *   **Gemini's Separation:** The Gemini code I generated initially kept the function separate from the user input and testing logic, demonstrating the function's reusability more directly.
#     *   **Why it matters:** For a standalone script, Copilot's integration is convenient. For a function that might be part of a larger library, Gemini's separation can be better for modularity and testing.
#
# ### Conclusion:
#
# Both Gemini and Copilot provide excellent, concise, and clear implementations. Copilot's inclusion of type hints is a notable advantage for code maintainability and clarity in a professional development context. However, Gemini's slightly more detailed docstring and the way its function was initially presented (separate from user interaction) could be argued as clearer for illustrating a reusable code component. Ultimately, both demonstrate a high level of code generation quality for this task.

# %% [markdown]
# # **Task 4: Code Explanation Using AI**

# %% [markdown]
# ❖ Scenario:
#
# You are reviewing unfamiliar code written by another developer.
#
# ❖ Task:
#
# Ask Gemini to explain a Python function (prime check OR palindrome
# check) line by line.
#
# ❖ Expected Output:
#
# ➢ Code snippet
#
# ➢ AI explanation
#
# ➢ Student comments on understanding

# %% [markdown]
# **Python function (prime check)**

# %%
# Prime number check with user input

def is_prime(n: int) -> bool:
    # Handle edge cases
    if n <= 1:
        return False
    if n == 2:
        return True
    if n % 2 == 0:
        return False

    # Check divisibility up to sqrt(n)
    for i in range(3, int(n**0.5) + 1, 2):
        if n % i == 0:
            return False
    return True

# Take input from user
num = int(input("Enter a number: "))

# Check and display result
if is_prime(num):
    print(f"✅ {num} is a prime number.")
else:
    print(f"❌ {num} is not a prime number.")
# Out:
# Enter a number: 23
# ✅ 23 is a prime number.

# %% [markdown]
# **AI Explanation: Line-by-Line Breakdown of `is_prime` function**
#
# Here's a detailed explanation of each significant line in the `is_prime` function:
#
# *   `def is_prime(n: int) -> bool:`
#     *   This defines a function named `is_prime`.
#     *   `n: int` specifies that the function expects one argument, `n`, which is an integer (this is a type hint).
#     *   `-> bool` specifies that the function is expected to return a boolean value (`True` or `False`) (this is also a type hint).
#
# *   `# Handle edge cases`
#     *   This is a comment indicating that the following lines deal with special conditions for prime numbers.
#
# *   `if n <= 1:`
#     *   This line checks if the input number `n` is less than or equal to 1. By definition, numbers less than or equal to 1 are not prime.
#
# *   `return False`
#     *   If `n` is 1 or less, the function immediately returns `False` because it's not a prime number.
#
# *   `if n == 2:`
#     *   This line checks if the input number `n` is exactly 2. The number 2 is the smallest and only even prime number.
#
# *   `return True`
#     *   If `n` is 2, the function immediately returns `True` because 2 is a prime number.
#
# *   `if n % 2 == 0:`
#     *   This line checks if `n` is an even number (i.e., its remainder when divided by 2 is 0). Since 2 is already handled, any other even number cannot be prime.
#
# *   `return False`
#     *   If `n` is an even number greater than 2, the function immediately returns `False` because it's not prime.
#
# *   `# Check divisibility up to sqrt(n)`
#     *   This comment explains the optimization used in the subsequent loop. We only need to check for divisors up to the square root of `n`.
#
# *   `for i in range(3, int(n**0.5) + 1, 2):`
#     *   This starts a `for` loop to check for odd divisors.
#     *   `range(3, ..., 2)` means the loop starts checking from 3 and increments by 2 in each step (so it checks only odd numbers).
#     *   `int(n**0.5) + 1` calculates the integer part of the square root of `n` and adds 1. This is the upper limit for checking divisors, as any factor larger than `sqrt(n)` would have a corresponding smaller factor already found.
#
# *   `if n % i == 0:`
#     *   Inside the loop, this line checks if `n` is perfectly divisible by the current odd number `i`.
#
# *   `return False`
#     *   If `n` is divisible by any `i` in the loop, it means `n` has a factor other than 1 and itself, so it's not prime. The function immediately returns `False`.
#
# *   `return True`
#     *   If the loop completes without finding any divisors, it means `n` has no factors other than 1 and itself (after handling edge cases), so it is a prime number. The function returns `True`.

# %% [markdown]
# **Student Comments on Understanding:**
#
# *   "The line-by-line explanation of the square root optimization was particularly helpful in understanding why the loop ends where it does. It makes the code much more efficient!"
#
# * "I found the detailed breakdown of the 'edge cases' (n <= 1, n == 2, n % 2 == 0) very clear. It's a logical way to handle the initial conditions for primality."
#
# * "The explanation of type hinting (n: int and -> bool) was useful. I now understand how it improves code readability and helps with code validation, which is a feature Copilot also provided."
#
# * "I appreciate how the comments within the code itself (like # Handle edge cases) align perfectly with the detailed explanation provided by the AI, making it easy to follow the logic."

# %% [markdown]
# ![image.png](data:image/png;base64,...)
